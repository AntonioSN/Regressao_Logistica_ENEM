# %%
import pandas as pd
import numpy as np
import seaborn as sns
DF = pd.read_csv('PIB_MUNICIPIOS.csv',engine="python",sep=";", decimal=',')
DF.head()
# Out:
# C:\Users\55279\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#     Ano  Código da Grande Região Nome da Grande Região
# 0  2010                        1                 Norte  \
# 1  2010                        1                 Norte
# 2  2010                        1                 Norte
# 3  2010                        1                 Norte
# 4  2010                        1                 Norte
#
#    Código da Unidade da Federação Sigla da Unidade da Federação
# 0                              11                            RO  \
# 1                              11                            RO
# 2                              11                            RO
# 3                              11                            RO
# ...

# %%
DF.columns
# Out:
# Index(['Ano', 'Código da Grande Região', 'Nome da Grande Região',
#        'Código da Unidade da Federação', 'Sigla da Unidade da Federação',
#        'Nome da Unidade da Federação', 'Código do Município',
#        'Nome do Município', 'Região Metropolitana', 'Código da Mesorregião',
#        'Nome da Mesorregião', 'Código da Microrregião', 'Nome da Microrregião',
#        'Código da Região Geográfica Imediata',
#        'Nome da Região Geográfica Imediata',
#        'Município da Região Geográfica Imediata',
#        'Código da Região Geográfica Intermediária',
#        'Nome da Região Geográfica Intermediária',
#        'Município da Região Geográfica Intermediária',
#        'Código Concentração Urbana', 'Nome Concentração Urbana',
#        'Tipo Concentração Urbana', 'Código Arranjo Populacional',
#        'Nome Arranjo Populacional', 'Hierarquia Urbana',
#        'Hierarquia Urbana (principais categorias)', 'Código da Região Rural',
#        'Nome da Região Rural',
# ...

# %%
DF.loc[DF["Nome do Município"]=="Vitória"].loc[DF["Ano"]==2019]
# Out:
#         Ano  Código da Grande Região Nome da Grande Região
# 53289  2019                        3               Sudeste  \
#
#        Código da Unidade da Federação Sigla da Unidade da Federação
# 53289                              32                            ES  \
#
#       Nome da Unidade da Federação  Código do Município Nome do Município
# 53289               Espírito Santo              3205309           Vitória  \
#
#                          Região Metropolitana  Código da Mesorregião  ...
# 53289  Região Metropolitana da Grande Vitória                   3203  ...  \
#
#       Valor adicionado bruto dos Serviços
# 53289                        1.222158e+07  \
#
#        Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social
# 53289                                        2000330.028                                               \
#
#       Valor adicionado bruto total     Impostos Produto Interno Bruto
# ...

# %%
DF.columns
# Out:
# Index(['Ano', 'Código da Grande Região', 'Nome da Grande Região',
#        'Código da Unidade da Federação', 'Sigla da Unidade da Federação',
#        'Nome da Unidade da Federação', 'Código do Município',
#        'Nome do Município', 'Região Metropolitana', 'Código da Mesorregião',
#        'Nome da Mesorregião', 'Código da Microrregião', 'Nome da Microrregião',
#        'Código da Região Geográfica Imediata',
#        'Nome da Região Geográfica Imediata',
#        'Município da Região Geográfica Imediata',
#        'Código da Região Geográfica Intermediária',
#        'Nome da Região Geográfica Intermediária',
#        'Município da Região Geográfica Intermediária',
#        'Código Concentração Urbana', 'Nome Concentração Urbana',
#        'Tipo Concentração Urbana', 'Código Arranjo Populacional',
#        'Nome Arranjo Populacional', 'Hierarquia Urbana',
#        'Hierarquia Urbana (principais categorias)', 'Código da Região Rural',
#        'Nome da Região Rural',
# ...

# %%
colunas = [
       'Valor adicionado bruto da Agropecuária',
       'Valor adicionado bruto da Indústria',
       'Valor adicionado bruto dos Serviços',
       'Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social',
       'Valor adicionado bruto total', 'Impostos', 'Produto Interno Bruto',
       'Produto Interno Bruto per capita'
        ]

sns.pairplot(DF[colunas])
# Out:
# C:\Users\55279\anaconda3\lib\site-packages\seaborn\axisgrid.py:1342: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout(pad=layout_pad)

# %%
DF.columns
# Out:
# Index(['Ano', 'Código da Grande Região', 'Nome da Grande Região',
#        'Código da Unidade da Federação', 'Sigla da Unidade da Federação',
#        'Nome da Unidade da Federação', 'Código do Município',
#        'Nome do Município', 'Região Metropolitana', 'Código da Mesorregião',
#        'Nome da Mesorregião', 'Código da Microrregião', 'Nome da Microrregião',
#        'Código da Região Geográfica Imediata',
#        'Nome da Região Geográfica Imediata',
#        'Município da Região Geográfica Imediata',
#        'Código da Região Geográfica Intermediária',
#        'Nome da Região Geográfica Intermediária',
#        'Município da Região Geográfica Intermediária',
#        'Código Concentração Urbana', 'Nome Concentração Urbana',
#        'Tipo Concentração Urbana', 'Código Arranjo Populacional',
#        'Nome Arranjo Populacional', 'Hierarquia Urbana',
#        'Hierarquia Urbana (principais categorias)', 'Código da Região Rural',
#        'Nome da Região Rural',
# ...
